# %% [markdown]
# STEP 1

# %%
# 1) data collection

# a) available data(csv, pdf,xlsx...)
# b) other data(database, internet,api, scraping)
# c) no data-> generate data:
#             using llms...


# if data is less then perform data augumentaion  -> because ->little data, the model can underfit or fail to generalize

# data augmentation is essential to increase the effective data size, improve generalization, 
# reduce overfitting, and make the model more reliable.

# %%
#data augumentation

# 1)biagram flip:
# i am aman
# aman is my name

# 2) img augumentation


# 3) replace with synonmous:
# i am a data scientist
# i am a ai engineer

# 4)back translate

# 5) add additional noise:
# i am a data scientist, i love my job

# %% [markdown]
# STEP 2

# %%
# Data preprocessing

# 1)cleanup (html, emoji, spelling correction)
# 2) basic preprocessing (tokenization -> 1) sentence 2) word)
# 3) optional (  1) stop word removal, 2)stemming  3)lemmitization 4) punctuation remove  4)lower case 5)lang detection)
# 4) advance preprocessing ( 1) parts of speech tagging  2)pasring  3)corefference resolution )

# %% [markdown]
# STEP 3

# %%
# feature enginnering

# text vectorization:
# tf-idf
# bow
# word2vec
# one hot
# transformers model

# %% [markdown]
# MODELLING

# %%
# models
# 1) open source  (llms)
# 2) paid model  (open ai,geminai)

# %% [markdown]
# MODEL EVALUATION

# %%
# evaluation:
# a) intrinsic ->metrics -> by genAi engineer
# b)extrinsic -> after edployent

# %% [markdown]
# DEPLOYMENT

# %%
#corpus (entire text)
# vocubulary(unique word)
#documments ( 1 row)
